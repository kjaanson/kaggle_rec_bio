# %%
from azureml.core import Experiment
from azureml.core import Workspace, Run
from azureml.core import Environment
from azureml.core import Dataset, Datastore

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core import ScriptRunConfig

# %%
from azureml.core.compute import ComputeInstance

# %%
workspace = Workspace.from_config()

# %%
instance = ComputeInstance(workspace=workspace, name='kaggle-gpu')

# %%
dataset = Dataset.get_by_name(workspace, name='recursionbio_zip')

# %%
dataset
# Out:
# {
#   "source": [
#     "('codefilestore', '/Users/kjaanson/recursionpharma/input/recursion-cellular-image-classification.zip')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "1e762845-e940-4179-b7b9-56313a8bb060",
#     "name": "recursionbio_zip",
#     "version": 5,
#     "workspace": "Workspace.create(name='bioworks-azureml', subscription_id='73f2271c-beee-4233-b5dd-202b520bf0db', resource_group='mslearn-azureml')"
#   }
# }

# %%
env_list = Environment.list(workspace)

# %%
env_list.keys()
# Out:
# dict_keys(['AzureML-PyTorch-1.3-GPU', 'AzureML-TensorFlow-2.0-CPU', 'AzureML-Tutorial', 'AzureML-PyTorch-1.3-CPU', 'AzureML-TensorFlow-2.0-GPU', 'AzureML-Chainer-5.1.0-GPU', 'AzureML-Minimal', 'AzureML-PyTorch-1.2-CPU', 'AzureML-TensorFlow-1.12-CPU', 'AzureML-TensorFlow-1.13-CPU', 'AzureML-PyTorch-1.1-CPU', 'AzureML-TensorFlow-1.10-CPU', 'AzureML-PyTorch-1.0-GPU', 'AzureML-TensorFlow-1.12-GPU', 'AzureML-TensorFlow-1.13-GPU', 'AzureML-Chainer-5.1.0-CPU', 'AzureML-PyTorch-1.0-CPU', 'AzureML-Scikit-learn-0.20.3', 'AzureML-PyTorch-1.2-GPU', 'AzureML-PyTorch-1.1-GPU', 'AzureML-TensorFlow-1.10-GPU', 'AzureML-PySpark-MmlSpark-0.15', 'AzureML-AutoML', 'AzureML-PyTorch-1.4-GPU', 'AzureML-PyTorch-1.4-CPU', 'AzureML-VowpalWabbit-8.8.0', 'AzureML-Hyperdrive-ForecastDNN', 'AzureML-AutoML-GPU', 'AzureML-AutoML-DNN', 'AzureML-PyTorch-1.5-CPU', 'AzureML-PyTorch-1.5-GPU', 'AzureML-Sidecar', 'AzureML-Designer-Score', 'AzureML-TensorFlow-2.1-GPU', 'AzureML-TensorFlow-2.1-CPU', 'AzureML-AutoML-DNN-Vision-GPU', 'AzureML-TensorFlow-2.2-GPU', 'AzureML-TensorFlow-2.2-CPU', 'AzureML-PyTorch-1.6-CPU', 'AzureML-PyTorch-1.6-GPU', 'AzureML-Triton', 'AzureML-TensorFlow-2.3-CPU', 'AzureML-TensorFlow-2.3-GPU', 'AzureML-DeepSpeed-0.3-GPU'])

# %%
tf_env = Environment.get(workspace=workspace, name='AzureML-TensorFlow-2.3-GPU')
tf_env = tf_env.clone(new_name='recbio-tf-2.3-efficientnet')

# %%
tf_env.python.conda_dependencies.add_conda_package('scikit-learn')
tf_env.python.conda_dependencies.add_conda_package('scipy')
tf_env.python.conda_dependencies.add_conda_package('matplotlib')

# %%
tf_env.python.conda_dependencies.add_pip_package('horovod==0.19.5')
tf_env.python.conda_dependencies.add_pip_package('retry')

# %%
tf_env
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "recbio-tf-2.3-efficientnet",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-core==1.18.0.post1",
#                         "azureml-defaults==1.18.0",
#                         "azureml-telemetry==1.18.0",
#                         "azureml-train-restclients-hyperdrive==1.18.0",
#                         "azureml-train-core==1.18.0",
#                         "tensorflow-gpu==2.3.0",
#                         "cmake==3.18.2",
#                         "horovod==0.19.5",
#                         "retry"
#                     ]
#                 },
#                 "scikit-learn",
#                 "scipy",
#                 "matplotlib"
#             ],
#             "name": "azureml_60ad88840fdbe40e31e03ddbbc134dec"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": null
# }

# %%
train_scr = ScriptRunConfig(
    source_directory='./scripts',
    script='train.py',
    arguments=['--data-file', dataset.as_mount()],
    compute_target=instance,
    environment=tf_env
)

# %%
train_scr

# %%
run = Experiment(workspace=workspace, name='RecBio-TF-Test').submit(train_scr)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: RecBio-TF-Test_1614086353_b28bdf1d
# Web View: https://ml.azure.com/experiments/RecBio-TF-Test/runs/RecBio-TF-Test_1614086353_b28bdf1d?wsid=/subscriptions/73f2271c-beee-4233-b5dd-202b520bf0db/resourcegroups/mslearn-azureml/workspaces/bioworks-azureml
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/02/23 13:19:19 Downloading source code...
# 2021/02/23 13:19:20 Finished downloading source code
# 2021/02/23 13:19:21 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/02/23 13:19:21 Successfully set up Docker network: acb_default_network
# 2021/02/23 13:19:21 Setting up Docker configuration...
# 2021/02/23 13:19:22 Successfully set up Docker configuration
# 2021/02/23 13:19:22 Logging in to registry: 2e7eaafe1ee440358c1d803ca534b890.azurecr.io
# 2021/02/23 13:19:23 Successfully logged into 2e7eaafe1ee440358c1d803ca534b890.azurecr.io
# 2021/02/23 13:19:23 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/23 13:19:23 Scanning for dependencies...
# 2021/02/23 13:19:24 Successfully scanned dependencies
# 2021/02/23 13:19:24 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1@sha256:99822e7a93465cf4612afe35a8bee126f9fc39913a119757dbd2b3024e0ac230
# sha256:99822e7a93465cf4612afe35a8bee126f9fc39913a119757dbd2b3024e0ac230: Pulling from azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
# 171857c49d0f: Pulling fs layer
# 419640447d26: Pulling fs layer
# 61e52f862619: Pulling fs layer
# c118dad7e37a: Pulling fs layer
# 2e36372995f9: Pulling fs layer
# 0b8e00a4ba4e: Pulling fs layer
# b3026b4f2581: Pulling fs layer
# 93cc193ccd98: Pulling fs layer
# ee06e59a4314: Pulling fs layer
# b0ac690bb2f2: Pulling fs layer
# 5f11ace0944e: Pulling fs layer
# dec11290bebb: Pulling fs layer
# 3c1a6d7dcb0d: Pulling fs layer
# c8f1065f1b2c: Pulling fs layer
# a5dfae9ae8d2: Pulling fs layer
# c77d1a6637be: Pulling fs layer
# 44808d4c7bff: Pulling fs layer
# e4653b04288f: Pulling fs layer
# d3ae0cdedade: Pulling fs layer
# c118dad7e37a: Waiting
# 2e36372995f9: Waiting
# 0b8e00a4ba4e: Waiting
# b3026b4f2581: Waiting
# 93cc193ccd98: Waiting
# ee06e59a4314: Waiting
# b0ac690bb2f2: Waiting
# 5f11ace0944e: Waiting
# dec11290bebb: Waiting
# 3c1a6d7dcb0d: Waiting
# c8f1065f1b2c: Waiting
# a5dfae9ae8d2: Waiting
# c77d1a6637be: Waiting
# 44808d4c7bff: Waiting
# e4653b04288f: Waiting
# d3ae0cdedade: Waiting
# 419640447d26: Verifying Checksum
# 419640447d26: Download complete
# 61e52f862619: Verifying Checksum
# 61e52f862619: Download complete
# c118dad7e37a: Verifying Checksum
# c118dad7e37a: Download complete
# 171857c49d0f: Verifying Checksum
# 171857c49d0f: Download complete
# 0b8e00a4ba4e: Verifying Checksum
# 0b8e00a4ba4e: Download complete
# 2e36372995f9: Verifying Checksum
# 2e36372995f9: Download complete
# 93cc193ccd98: Verifying Checksum
# 93cc193ccd98: Download complete
# b0ac690bb2f2: Verifying Checksum
# b0ac690bb2f2: Download complete
# 171857c49d0f: Pull complete
# 419640447d26: Pull complete
# 61e52f862619: Pull complete
# c118dad7e37a: Pull complete
# 5f11ace0944e: Verifying Checksum
# 5f11ace0944e: Download complete
# 2e36372995f9: Pull complete
# 0b8e00a4ba4e: Pull complete
# b3026b4f2581: Verifying Checksum
# b3026b4f2581: Download complete
# 3c1a6d7dcb0d: Verifying Checksum
# 3c1a6d7dcb0d: Download complete
# ee06e59a4314: Verifying Checksum
# ee06e59a4314: Download complete
# c8f1065f1b2c: Verifying Checksum
# c8f1065f1b2c: Download complete
# c77d1a6637be: Verifying Checksum
# c77d1a6637be: Download complete
# 44808d4c7bff: Verifying Checksum
# 44808d4c7bff: Download complete
# e4653b04288f: Verifying Checksum
# e4653b04288f: Download complete
# a5dfae9ae8d2: Verifying Checksum
# a5dfae9ae8d2: Download complete
# d3ae0cdedade: Verifying Checksum
# d3ae0cdedade: Download complete
# dec11290bebb: Verifying Checksum
# dec11290bebb: Download complete
# b3026b4f2581: Pull complete
# 93cc193ccd98: Pull complete
#
# ee06e59a4314: Pull complete
# b0ac690bb2f2: Pull complete
#
# 5f11ace0944e: Pull complete
# dec11290bebb: Pull complete
# 3c1a6d7dcb0d: Pull complete
# c8f1065f1b2c: Pull complete
# a5dfae9ae8d2: Pull complete
# c77d1a6637be: Pull complete
# 44808d4c7bff: Pull complete
# e4653b04288f: Pull complete
# d3ae0cdedade: Pull complete
# Digest: sha256:99822e7a93465cf4612afe35a8bee126f9fc39913a119757dbd2b3024e0ac230
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1@sha256:99822e7a93465cf4612afe35a8bee126f9fc39913a119757dbd2b3024e0ac230
#  ---> 1c12b76952ee
# Step 2/18 : USER root
#  ---> Running in 41762621d534
# Removing intermediate container 41762621d534
#  ---> b04d3a16eae6
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in d5a8ecc54469
# Removing intermediate container d5a8ecc54469
#  ---> 2c59e1f5e2a0
# Step 4/18 : WORKDIR /
#  ---> Running in 7aac1bc6cc75
# Removing intermediate container 7aac1bc6cc75
#  ---> a89961ffcccc
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 86053f6a082d
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 172c82744547
# Removing intermediate container 172c82744547
#  ---> 89641f63d640
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 9e702ddfe1ed
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 78406ac9c61b
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# zstd-1.4.8           | 702 KB    |            |   0%
# zstd-1.4.8           | 702 KB    | ########## | 100%
#
# setuptools-49.6.0    | 936 KB    |            |   0%
# setuptools-49.6.0    | 936 KB    | ########## | 100%
#
# xz-5.2.5             | 343 KB    |            |   0%
# xz-5.2.5             | 343 KB    | ########## | 100%
#
# numpy-1.19.5         | 5.3 MB    |            |   0%
# numpy-1.19.5         | 5.3 MB    | ########## | 100%
#
# freetype-2.10.4      | 890 KB    |            |   0%
# freetype-2.10.4      | 890 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 179 KB    |            |   0%
# lz4-c-1.9.3          | 179 KB    | ########## | 100%
#
# liblapack-3.9.0      | 11 KB     |            |   0%
# liblapack-3.9.0      | 11 KB     | ########## | 100%
#
# joblib-1.0.1         | 206 KB    |            |   0%
# joblib-1.0.1         | 206 KB    | ########## | 100%
#
# readline-6.2         | 713 KB    |            |   0%
# readline-6.2         | 713 KB    | ########## | 100%
#
# libgomp-9.3.0        | 376 KB    |            |   0%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
#
# libopenblas-0.3.12   | 8.9 MB    |            |   0%
# libopenblas-0.3.12   | 8.9 MB    | #######4   |  75%
# libopenblas-0.3.12   | 8.9 MB    | ########## | 100%
#
# libwebp-base-1.2.0   | 808 KB    |            |   0%
# libwebp-base-1.2.0   | 808 KB    | ########## | 100%
#
# tk-8.5.19            | 1.9 MB    |            |   0%
# tk-8.5.19            | 1.9 MB    |            |   1%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
#
# libcblas-3.9.0       | 11 KB     |            |   0%
# libcblas-3.9.0       | 11 KB     | ########## | 100%
#
# libgcc-ng-9.3.0      | 7.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 7.8 MB    | ######6    |  66%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
#
# lcms2-2.12           | 443 KB    |            |   0%
# lcms2-2.12           | 443 KB    | ########## | 100%
#
# tornado-6.1          | 643 KB    |            |   0%
# tornado-6.1          | 643 KB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# python-3.6.2         | 19.0 MB   |            |   0%
# python-3.6.2         | 19.0 MB   | #4         |  15%
# python-3.6.2         | 19.0 MB   | ####       |  41%
# python-3.6.2         | 19.0 MB   | #######4   |  75%
# python-3.6.2         | 19.0 MB   | ########## | 100%
#
# scipy-1.5.3          | 19.1 MB   |            |   0%
# scipy-1.5.3          | 19.1 MB   | ###4       |  35%
# scipy-1.5.3          | 19.1 MB   | ########2  |  82%
# scipy-1.5.3          | 19.1 MB   | ########## | 100%
#
# cycler-0.10.0        | 9 KB      |            |   0%
# cycler-0.10.0        | 9 KB      | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# ca-certificates-2020 | 137 KB    |            |   0%
# ca-certificates-2020 | 137 KB    | ########## | 100%
#
# wheel-0.36.2         | 31 KB     |            |   0%
# wheel-0.36.2         | 31 KB     | ########## | 100%
#
# libpng-1.6.37        | 306 KB    |            |   0%
# libpng-1.6.37        | 306 KB    | ########## | 100%
#
# pip-21.0.1           | 1.1 MB    |            |   0%
# pip-21.0.1           | 1.1 MB    | ########## | 100%
#
# jpeg-9d              | 264 KB    |            |   0%
# jpeg-9d              | 264 KB    | ########## | 100%
#
# libblas-3.9.0        | 11 KB     |            |   0%
# libblas-3.9.0        | 11 KB     | ########## | 100%
#
# libgfortran-ng-9.3.0 | 22 KB     |            |   0%
# libgfortran-ng-9.3.0 | 22 KB     | ########## | 100%
#
# olefile-0.46         | 32 KB     |            |   0%
# olefile-0.46         | 32 KB     | ########## | 100%
#
# sqlite-3.13.0        | 4.9 MB    |            |   0%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 60 KB     |            |   0%
# pyparsing-2.4.7      | 60 KB     | ########## | 100%
#
# kiwisolver-1.3.1     | 78 KB     |            |   0%
# kiwisolver-1.3.1     | 78 KB     | ########## | 100%
#
# six-1.15.0           | 14 KB     |            |   0%
# six-1.15.0           | 14 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 15 KB     |            |   0%
# threadpoolctl-2.1.0  | 15 KB     | ########## | 100%
#
# matplotlib-3.3.2     | 6 KB      |            |   0%
# matplotlib-3.3.2     | 6 KB      | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
#
# python-dateutil-2.8. | 220 KB    |            |   0%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
#
# certifi-2020.12.5    | 143 KB    |            |   0%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ######1    |  62%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# pillow-8.1.0         | 626 KB    |            |   0%
# pillow-8.1.0         | 626 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# ncurses-5.9          | 1.1 MB    |            |   0%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
#
# libtiff-4.2.0        | 633 KB    |            |   0%
# libtiff-4.2.0        | 633 KB    | ########## | 100%
#
# libgfortran5-9.3.0   | 2.0 MB    |            |   0%
# libgfortran5-9.3.0   | 2.0 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# zlib-1.2.11          | 106 KB    |            |   0%
# zlib-1.2.11          | 106 KB    | ########## | 100%
#
# scikit-learn-0.24.1  | 7.5 MB    |            |   0%
# scikit-learn-0.24.1  | 7.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.n080l6vq.requirements.txt']
# Pip subprocess output:
# Collecting azureml-core==1.18.0.post1
#   Downloading azureml_core-1.18.0.post1-py3-none-any.whl (2.1 MB)
# Collecting azureml-defaults==1.18.0
#   Downloading azureml_defaults-1.18.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-telemetry==1.18.0
#   Downloading azureml_telemetry-1.18.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-restclients-hyperdrive==1.18.0
#   Downloading azureml_train_restclients_hyperdrive-1.18.0-py3-none-any.whl (19 kB)
# Collecting azureml-train-core==1.18.0
#   Downloading azureml_train_core-1.18.0-py3-none-any.whl (8.6 MB)
# Collecting tensorflow-gpu==2.3.0
#   Downloading tensorflow_gpu-2.3.0-cp36-cp36m-manylinux2010_x86_64.whl (320.4 MB)
# Collecting cmake==3.18.2
#   Downloading cmake-3.18.2-py3-none-manylinux1_x86_64.whl (18.2 MB)
# Collecting horovod==0.19.5
#   Downloading horovod-0.19.5.tar.gz (2.9 MB)
# Collecting retry
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting docker
#   Downloading docker-4.4.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/python3.6/site-packages (from azureml-core==1.18.0.post1->-r /azureml-environment-setup/condaenv.n080l6vq.requirements.txt (line 1)) (2.8.1)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.6-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.18.0
#   Downloading azureml_dataset_runtime-1.18.0-py3-none-any.whl (3.4 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting psutil
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (640 kB)
# Requirement already satisfied: six in /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/python3.6/site-packages (from horovod==0.19.5->-r /azureml-environment-setup/condaenv.n080l6vq.requirements.txt (line 8)) (1.15.0)
# Collecting cffi>=1.4.0
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.15.1-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# Collecting keras-preprocessing<1.2,>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting tensorboard<3,>=2.3.0
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
# Requirement already satisfied: wheel>=0.26 in /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/python3.6/site-packages (from tensorflow-gpu==2.3.0->-r /azureml-environment-setup/condaenv.n080l6vq.requirements.txt (line 6)) (0.36.2)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.35.0-cp36-cp36m-manylinux2014_x86_64.whl (4.1 MB)
# Collecting google-pasta>=0.1.8
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting azureml-dataprep<2.5.0a,>=2.4.0a
#   Downloading azureml_dataprep-2.4.5-py3-none-any.whl (28.2 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.3-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.11.0-py2.py3-none-any.whl (127 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.9.0-py2.py3-none-any.whl (59 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==1.18.0.post1->-r /azureml-environment-setup/condaenv.n080l6vq.requirements.txt (line 1)) (2020.12.5)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.0.0-py3-none-any.whl (15 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.27.0-py2.py3-none-any.whl (135 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/python3.6/site-packages (from tensorboard<3,>=2.3.0->tensorflow-gpu==2.3.0->-r /azureml-environment-setup/condaenv.n080l6vq.requirements.txt (line 6)) (49.6.0.post20210108)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.1-py3-none-any.whl (36 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting decorator>=3.4.2
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting py<2.0.0,>=1.4.26
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Building wheels for collected packages: horovod, json-logging-py, fusepy, liac-arff, termcolor, wrapt
#   Building wheel for horovod (setup.py): started
#   Building wheel for horovod (setup.py): finished with status 'error'
#   Running setup.py clean for horovod
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=f529af78a3a5262346ac6cd1bd519cfb47b07138266ec155637eecfdfb672062
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=06834e06809351bfa8924b6c9603405e81e454b1d63559228b37ec8ad6dc218c
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=fbfaa628276e1316a04284b5d47bc1000f0aed3391e89517c8265913b9ca2bd8
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=b1dbdc465960af2a001dcc72c7ca345c8f20c0b3165cf499e77e86366798c9f3
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69925 sha256=ac4e1e66b95888775fa69c745c5f40ad822d79d9eb0e061e6217b2e7899b5189
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy liac-arff termcolor wrapt
# Failed to build horovod
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, chardet, requests, oauthlib, requests-oauthlib, portalocker, msal, isodate, zipp, typing-extensions, pyasn1, msrest, msal-extensions, distro, azure-core, adal, websocket-client, ruamel.yaml.clib, rsa, pyopenssl, pyasn1-modules, numpy, msrestazure, jeepney, importlib-metadata, dotnetcore2, cloudpickle, cachetools, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, azure-common, SecretStorage, ruamel.yaml, pytz, pyarrow, pathspec, ndg-httpsclient, MarkupSafe, jsonpickle, jmespath, google-auth, docker, contextlib2, backports.tempfile, azureml-dataprep, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, werkzeug, tensorboard-plugin-wit, protobuf, pandas, markdown, liac-arff, Jinja2, itsdangerous, grpcio, google-auth-oauthlib, fusepy, dill, click, azureml-dataset-runtime, azureml-core, applicationinsights, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, scipy, pyyaml, py, psutil, opt-einsum, keras-preprocessing, json-logging-py, h5py, gunicorn, google-pasta, gast, flask, decorator, configparser, azureml-train-restclients-hyperdrive, azureml-telemetry, azureml-model-management-sdk, astunparse, tensorflow-gpu, retry, horovod, cmake, azureml-train-core, azureml-defaults
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.5.3
#     Uninstalling scipy-1.5.3:
#       Successfully uninstalled scipy-1.5.3
#     Running setup.py install for horovod: started
#     Running setup.py install for horovod: still running...
#     Running setup.py install for horovod: finished with status 'done'
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.1 absl-py-0.11.0 adal-1.2.6 applicationinsights-0.11.9 astunparse-1.6.3 azure-common-1.1.26 azure-core-1.11.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.18.0.post1 azureml-dataprep-2.4.5 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.3 azureml-dataset-runtime-1.18.0 azureml-defaults-1.18.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-telemetry-1.18.0 azureml-train-core-1.18.0 azureml-train-restclients-hyperdrive-1.18.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 cmake-3.18.2 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.6 decorator-4.4.2 dill-0.3.3 distro-1.5.0 docker-4.4.3 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gast-0.3.3 google-auth-1.27.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.35.0 gunicorn-19.9.0 h5py-2.10.0 horovod-0.19.5 idna-2.10 importlib-metadata-3.4.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 keras-preprocessing-1.1.2 liac-arff-2.5.0 markdown-3.3.3 msal-1.9.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.18.5 oauthlib-3.1.0 opt-einsum-3.3.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 protobuf-3.15.1 psutil-5.8.0 py-1.10.0 pyarrow-1.0.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-19.1.0 pytz-2021.1 pyyaml-5.4.1 requests-2.25.1 requests-oauthlib-1.3.0 retry-0.9.2 rsa-4.7.1 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 scipy-1.4.1 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-estimator-2.3.0 tensorflow-gpu-2.3.0 termcolor-1.1.0 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.57.0 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.4.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 78406ac9c61b
#  ---> 534dd1196e50
# Step 9/18 : ENV PATH /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/bin:$PATH
#  ---> Running in 0d9b601ef656
# Removing intermediate container 0d9b601ef656
#  ---> bd1965ec902d
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> fb82e9d82f14
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> a39eaed75291
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565
#  ---> Running in c33df910e7f7
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container c33df910e7f7
#  ---> 1d6340296aca
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565
#  ---> Running in fe01a8f149fe
# Removing intermediate container fe01a8f149fe
#  ---> 3e6546118ee0
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib:$LD_LIBRARY_PATH
#  ---> Running in 398ef4c835f2
# Removing intermediate container 398ef4c835f2
#  ---> c90c6951296b
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 4efe56e04cec
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 0d15bb158d38
# Removing intermediate container 0d15bb158d38
#  ---> 1367091d5e07
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 6c1ea2ebe4b8
# Removing intermediate container 6c1ea2ebe4b8
#  ---> c486555475ee
# Step 18/18 : CMD ["bash"]
#  ---> Running in e6fa8bb5bf88
# Removing intermediate container e6fa8bb5bf88
#  ---> 03006e69545e
# Successfully built 03006e69545e
# Successfully tagged 2e7eaafe1ee440358c1d803ca534b890.azurecr.io/azureml/azureml_a80319b88ee33a4eda3965ec611d6dda:latest
# 2021/02/23 13:27:50 Successfully executed container: acb_step_0
# 2021/02/23 13:27:50 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/23 13:27:50 Pushing image: 2e7eaafe1ee440358c1d803ca534b890.azurecr.io/azureml/azureml_a80319b88ee33a4eda3965ec611d6dda:latest, attempt 1
# The push refers to repository [2e7eaafe1ee440358c1d803ca534b890.azurecr.io/azureml/azureml_a80319b88ee33a4eda3965ec611d6dda]
# 3460fdf2232b: Preparing
# bc78dc95b40f: Preparing
# 12835a328838: Preparing
# 4496eb688909: Preparing
# 35f23f93bf94: Preparing
# 1dfe9c5dd775: Preparing
# 2f5ea02cd13b: Preparing
# f691606356db: Preparing
# 5f0d762c97ba: Preparing
# c0df84823216: Preparing
# 27133bba85cb: Preparing
# 90d2c816690f: Preparing
# aeeef70899ab: Preparing
# 2da82231265b: Preparing
# 33644d1ff76a: Preparing
# 251f7e164e9b: Preparing
# 0159cb46c27b: Preparing
# 7bbcc92dda8d: Preparing
# 15aff59a9f72: Preparing
# 046d149a288f: Preparing
# 9327904150fd: Preparing
# e3aa3988e482: Preparing
# 4ec277bdf61d: Preparing
# 7b9520c9f3d7: Preparing
# 7d85c7820671: Preparing
# 7a694df0ad6c: Preparing
# 3fd9df553184: Preparing
# 805802706667: Preparing
# 1dfe9c5dd775: Waiting
# 2f5ea02cd13b: Waiting
# f691606356db: Waiting
# 5f0d762c97ba: Waiting
# c0df84823216: Waiting
# 27133bba85cb: Waiting
# 90d2c816690f: Waiting
# aeeef70899ab: Waiting
# 2da82231265b: Waiting
# 33644d1ff76a: Waiting
# 251f7e164e9b: Waiting
# 0159cb46c27b: Waiting
# 7bbcc92dda8d: Waiting
# 15aff59a9f72: Waiting
# 046d149a288f: Waiting
# 9327904150fd: Waiting
# e3aa3988e482: Waiting
# 4ec277bdf61d: Waiting
# 7b9520c9f3d7: Waiting
# 7d85c7820671: Waiting
# 7a694df0ad6c: Waiting
# 3fd9df553184: Waiting
# 805802706667: Waiting
# 12835a328838: Pushed
# 3460fdf2232b: Pushed
# 4496eb688909: Pushed
# bc78dc95b40f: Pushed
# 2f5ea02cd13b: Pushed
# f691606356db: Pushed
# 1dfe9c5dd775: Pushed
# 5f0d762c97ba: Pushed
# c0df84823216: Pushed
# 27133bba85cb: Pushed
# 90d2c816690f: Pushed
# aeeef70899ab: Pushed
# 33644d1ff76a: Pushed
# 251f7e164e9b: Pushed
# 15aff59a9f72: Pushed
# 2da82231265b: Pushed
# 9327904150fd: Pushed
# 7bbcc92dda8d: Pushed
# 4ec277bdf61d: Pushed
# 7b9520c9f3d7: Pushed
# 7d85c7820671: Pushed
# 7a694df0ad6c: Pushed
# 3fd9df553184: Pushed
# 805802706667: Pushed
# e3aa3988e482: Pushed
# 046d149a288f: Pushed
# 35f23f93bf94: Pushed
# 0159cb46c27b: Pushed
# latest: digest: sha256:fb012f314d5aadee2eff21cfbd919567b717dcefc5269c76d8394a433b72c087 size: 6199
# 2021/02/23 13:34:20 Successfully pushed image: 2e7eaafe1ee440358c1d803ca534b890.azurecr.io/azureml/azureml_a80319b88ee33a4eda3965ec611d6dda:latest
# 2021/02/23 13:34:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 507.405470)
# 2021/02/23 13:34:20 Populating digests for step ID: acb_step_0...
# 2021/02/23 13:34:21 Successfully populated digests for step ID: acb_step_0
# 2021/02/23 13:34:21 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 389.400253)
# 2021/02/23 13:34:21 The following dependencies were found:
# 2021/02/23 13:34:21
# - image:
#     registry: 2e7eaafe1ee440358c1d803ca534b890.azurecr.io
#     repository: azureml/azureml_a80319b88ee33a4eda3965ec611d6dda
#     tag: latest
#     digest: sha256:fb012f314d5aadee2eff21cfbd919567b717dcefc5269c76d8394a433b72c087
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
#     tag: 20201112.v1
#     digest: sha256:99822e7a93465cf4612afe35a8bee126f9fc39913a119757dbd2b3024e0ac230
#   git: {}
#
#
# Run ID: cg9 was successful after 15m3s
#
# Streaming azureml-logs/65_job_prep-tvmps_69e8457cd90cff5fb34be78c15a3e7875b7f971571ea725123939d31d90e5c60_d.txt
# ===============================================================================================================
#
# [2021-02-23T13:34:58.546691] Entering job preparation.
# [2021-02-23T13:35:03.799955] Starting job preparation.
# [2021-02-23T13:35:03.799990] Extracting the control code.
# [2021-02-23T13:35:03.818546] fetching and extracting the control code on master node.
# [2021-02-23T13:35:03.818579] Starting extract_project.
# [2021-02-23T13:35:03.818618] Starting to extract zip file.
# [2021-02-23T13:35:04.524981] Finished extracting zip file.
# [2021-02-23T13:35:04.670566] Using urllib.request Python 3.0 or later
# [2021-02-23T13:35:04.670631] Start fetching snapshots.
# [2021-02-23T13:35:04.670674] Start fetching snapshot.
# [2021-02-23T13:35:04.670691] Retrieving project from snapshot: d81f4939-c1cf-4a6b-ad9f-57c2525752b2
# Starting the daemon thread to refresh tokens in background for process with pid = 29
# [2021-02-23T13:35:05.322724] Finished fetching snapshot.
# [2021-02-23T13:35:05.322758] Finished fetching snapshots.
# [2021-02-23T13:35:05.322774] Finished extract_project.
# [2021-02-23T13:35:05.333334] Finished fetching and extracting the control code.
# [2021-02-23T13:35:05.339874] Start run_history_prep.
# [2021-02-23T13:35:05.566558] Job preparation is complete.
# [2021-02-23T13:35:05.566612] Entering Data Context Managers in Sidecar
# [2021-02-23T13:35:05.567287] Running Sidecar prep cmd...
# [2021-02-23T13:35:05.622331] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/mounts/workspaceblobstore/azureml/RecBio-TF-Test_1614086353_b28bdf1d
# [2021-02-23T13:35:05.623037] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.21.0.post2 azureml-dataprep==2.9.1. Session id: 93367922-0611-47a7-b936-93c8f1915e89. Run id: RecBio-TF-Test_1614086353_b28bdf1d.
# Processing 'input__d34384c1'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('codefilestore', '/Users/kjaanson/recursionpharma/input/recursion-cellular-image-classification.zip')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "1e762845-e940-4179-b7b9-56313a8bb060",
#     "name": "recursionbio_zip",
#     "version": 5,
#     "workspace": "Workspace.create(name='bioworks-azureml', subscription_id='73f2271c-beee-4233-b5dd-202b520bf0db', resource_group='mslearn-azureml')"
#   }
# }
# Mounting input__d34384c1 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/wd/tmpphti1cmg.
# Mounted input__d34384c1 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/wd/tmpphti1cmg as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__d34384c1's target path to /mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/wd/tmpphti1cmg/recursion-cellular-image-classification.zip
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# [2021-02-23T13:35:23.357271] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-02-23T13:35:25.311109] Ran Sidecar prep cmd.
# [2021-02-23T13:35:25.311154] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_bdfb997b3bc46ee92543840814133565/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/02/23 13:36:40 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/02/23 13:36:40 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-02-23T13:36:41.381449] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train.py', '--data-file', 'DatasetConsumptionConfig:input__d34384c1'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 72
# [2021-02-23T13:36:43.323878] Entering Run History Context Manager.
# [2021-02-23T13:36:44.381117] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/mounts/workspaceblobstore/azureml/RecBio-TF-Test_1614086353_b28bdf1d
# [2021-02-23T13:36:44.381318] Preparing to call script [train.py] with arguments:['--data-file', '$input__d34384c1']
# [2021-02-23T13:36:44.381747] After variable expansion, calling script [train.py] with arguments:['--data-file', '/mnt/batch/tasks/shared/LS_root/jobs/bioworks-azureml/azureml/recbio-tf-test_1614086353_b28bdf1d/wd/tmpphti1cmg/recursion-cellular-image-classification.zip']
#
# 2021-02-23 13:36:44.990038: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#